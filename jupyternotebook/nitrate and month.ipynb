# %%
import pandas as pd

# %%
nitrate = pd.read_csv("nitrate_usefull.csv")

# %%
nitrate
# Out:
#        messstelle_id  gemeinde_id     name             datum_pn  stoff_nr  \
# 0           10131310      5366044  Zülpich  1999-03-18 00:00:00      1244
# 1           10131310      5366044  Zülpich  2008-01-24 00:00:00      1244
# 2           10131310      5366044  Zülpich  1989-09-20 00:00:00      1244
# 3           10131310      5366044  Zülpich  1994-11-29 00:00:00      1244
# 4           10131310      5366044  Zülpich  2001-03-13 00:00:00      1244
# ...              ...          ...      ...                  ...       ...
# 73894      289196413      5162024    Neuss  2004-09-08 00:00:00      1244
# 73895      289196413      5162024    Neuss  2013-04-17 00:00:00      1244
# 73896      289196413      5162024    Neuss  2002-04-09 00:00:00      1244
# 73897      289196413      5162024    Neuss  2011-07-14 00:00:00      1244
# 73898      289196413      5162024    Neuss  2009-03-18 00:00:00      1244
#
#        messergebnis_c masseinheit                    messergebnis_hinweis  \
# ...

# %%
nitrate.dtypes
# Out:
# messstelle_id                int64
# gemeinde_id                  int64
# name                        object
# datum_pn                    object
# stoff_nr                     int64
# messergebnis_c             float64
# masseinheit                 object
# messergebnis_hinweis        object
# gw_stockwerk               float64
# grundstueck                 object
# gwhorizont                  object
# gwleiter                    object
# gwk_lage_id                 object
# gwk_monitoring_id           object
# turnus_wasserstand          object
# wasserstandsmessstelle      object
# guetemessstelle             object
# beobachtung_wasserstand     object
# betreiber                   object
# filterlaenge_cm            float64
# ausbaudurchmesser_mm       float64
# historischer_ruhe_wsp      float64
# oberkante_filter_cm        float64
# probengut                   object
# verfahren                   object
# messergebnis_cm             object
# dtype: object

# %%
nitrate['datum_pn'] = pd.to_datetime(nitrate['datum_pn'], format = '%Y-%m-%d')

# %%
nitrate
# Out:
#        messstelle_id  gemeinde_id     name   datum_pn  stoff_nr  \
# 0           10131310      5366044  Zülpich 1999-03-18      1244
# 1           10131310      5366044  Zülpich 2008-01-24      1244
# 2           10131310      5366044  Zülpich 1989-09-20      1244
# 3           10131310      5366044  Zülpich 1994-11-29      1244
# 4           10131310      5366044  Zülpich 2001-03-13      1244
# ...              ...          ...      ...        ...       ...
# 73894      289196413      5162024    Neuss 2004-09-08      1244
# 73895      289196413      5162024    Neuss 2013-04-17      1244
# 73896      289196413      5162024    Neuss 2002-04-09      1244
# 73897      289196413      5162024    Neuss 2011-07-14      1244
# 73898      289196413      5162024    Neuss 2009-03-18      1244
#
#        messergebnis_c masseinheit                    messergebnis_hinweis  \
# 0            35.41600        mg/l                                     NaN
# ...

# %%
nitrate.dtypes
# Out:
# messstelle_id                       int64
# gemeinde_id                         int64
# name                               object
# datum_pn                   datetime64[ns]
# stoff_nr                            int64
# messergebnis_c                    float64
# masseinheit                        object
# messergebnis_hinweis               object
# gw_stockwerk                      float64
# grundstueck                        object
# gwhorizont                         object
# gwleiter                           object
# gwk_lage_id                        object
# gwk_monitoring_id                  object
# turnus_wasserstand                 object
# wasserstandsmessstelle             object
# guetemessstelle                    object
# beobachtung_wasserstand            object
# betreiber                          object
# filterlaenge_cm                   float64
# ausbaudurchmesser_mm              float64
# historischer_ruhe_wsp             float64
# ...

# %%
nitrate['month_c'] = pd.to_datetime(nitrate['datum_pn']).dt.month
nitrate.head()
# Out:
#    messstelle_id  gemeinde_id     name   datum_pn  stoff_nr  messergebnis_c  \
# 0       10131310      5366044  Zülpich 1999-03-18      1244        35.41600
# 1       10131310      5366044  Zülpich 2008-01-24      1244         7.26028
# 2       10131310      5366044  Zülpich 1989-09-20      1244        24.31308
# 3       10131310      5366044  Zülpich 1994-11-29      1244        47.36890
# 4       10131310      5366044  Zülpich 2001-03-13      1244        14.60910
#
#   masseinheit messergebnis_hinweis  gw_stockwerk grundstueck  ...  \
# 0        mg/l                  NaN           2.0      privat  ...
# 1        mg/l                  NaN           2.0      privat  ...
# 2        mg/l                  NaN           2.0      privat  ...
# 3        mg/l                  NaN           2.0      privat  ...
# 4        mg/l                  NaN           2.0      privat  ...
#
#   beobachtung_wasserstand                                          betreiber  \
# ...

# %%
nitrate
# Out:
#        messstelle_id  gemeinde_id     name   datum_pn  stoff_nr  \
# 0           10131310      5366044  Zülpich 1999-03-18      1244
# 1           10131310      5366044  Zülpich 2008-01-24      1244
# 2           10131310      5366044  Zülpich 1989-09-20      1244
# 3           10131310      5366044  Zülpich 1994-11-29      1244
# 4           10131310      5366044  Zülpich 2001-03-13      1244
# ...              ...          ...      ...        ...       ...
# 73894      289196413      5162024    Neuss 2004-09-08      1244
# 73895      289196413      5162024    Neuss 2013-04-17      1244
# 73896      289196413      5162024    Neuss 2002-04-09      1244
# 73897      289196413      5162024    Neuss 2011-07-14      1244
# 73898      289196413      5162024    Neuss 2009-03-18      1244
#
#        messergebnis_c masseinheit                    messergebnis_hinweis  \
# 0            35.41600        mg/l                                     NaN
# ...

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:Leomessi@localhost:5432/nitratescout")

# %%
# %time nitrate.to_sql(con=engine, name="nitrate_month", schema="public", if_exists="replace", index=False)
# Out:
# CPU times: total: 4.42 s
# Wall time: 7.75 s
# 899
