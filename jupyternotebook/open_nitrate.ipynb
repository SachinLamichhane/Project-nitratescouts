# %% [markdown]
# The aim of this file is to import only the useful dataset such as nitrate, nitrit acquired from the database table open_messwert and upload it to our database for further analysis.

# %%
import pandas as pd
import sqlalchemy

# %%
data_in_dir= r"../data/"

gw_quality_fname = r"open_nitrate.csv"

gw_quality_pfname = data_in_dir + gw_quality_fname

# %% [markdown]
# Above mentioned steps imports datasets and read it.

# %%
df = pd.read_csv(gw_quality_pfname, sep = ",")
df.head()
# Out:
#    stoff_nr               name  beschreibung  cas_id  messstelle_id  \
# 0      1245  Nitrat-Stickstoff           NaN     NaN       40200504
# 1      1245  Nitrat-Stickstoff           NaN     NaN       40507014
# 2      1245  Nitrat-Stickstoff           NaN     NaN       21000610
# 3      1247  Nitrit-Stickstoff           NaN     NaN       21000610
# 4      1245  Nitrat-Stickstoff           NaN     NaN       40200863
#
#          pna_id                   datum_pn  stoff_nr-2    probengut  \
# 0   6/2005/4108  1970-01-01 00:00:00.02005        1245  Grundwasser
# 1   6/2005/4150  1970-01-01 00:00:00.02005        1245  Grundwasser
# 2  10/2005/2047  1970-01-01 00:00:00.02005        1245  Grundwasser
# 3  10/2005/2047  1970-01-01 00:00:00.02005        1247  Grundwasser
# 4   6/2005/4110  1970-01-01 00:00:00.02005        1245  Grundwasser
#
#    messergebnis_c messergebnis_hinweis  bestimmungsgrenze masseinheit  \
# 0           22.10                  NaN                NaN        mg/l
# ...

# %%
df = df.drop("stoff_nr-2", axis=1)

# %%
dropping the stoff nr column since it has appeared twice as we retrieved this table from joining two tables from SQL

# %%
df.head()
# Out:
#    stoff_nr               name  beschreibung  cas_id  messstelle_id  \
# 0      1245  Nitrat-Stickstoff           NaN     NaN       40200504
# 1      1245  Nitrat-Stickstoff           NaN     NaN       40507014
# 2      1245  Nitrat-Stickstoff           NaN     NaN       21000610
# 3      1247  Nitrit-Stickstoff           NaN     NaN       21000610
# 4      1245  Nitrat-Stickstoff           NaN     NaN       40200863
#
#          pna_id                   datum_pn    probengut  messergebnis_c  \
# 0   6/2005/4108  1970-01-01 00:00:00.02005  Grundwasser           22.10
# 1   6/2005/4150  1970-01-01 00:00:00.02005  Grundwasser            2.10
# 2  10/2005/2047  1970-01-01 00:00:00.02005  Grundwasser            5.70
# 3  10/2005/2047  1970-01-01 00:00:00.02005  Grundwasser            0.03
# 4   6/2005/4110  1970-01-01 00:00:00.02005  Grundwasser            1.20
#
#   messergebnis_hinweis  bestimmungsgrenze masseinheit trennverfahren  \
# ...

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:Leomessi@localhost:5432/nitratescout")

# %% [markdown]
# creating a engine to connect database with python

# %%
# %time df.to_sql(con=engine, name="open_nitrate", schema="sachin", if_exists="replace", index=False)
# Out:
# CPU times: total: 8.39 s
# Wall time: 14.6 s
# 537
